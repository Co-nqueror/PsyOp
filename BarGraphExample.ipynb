# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("Dataset.db")
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)

df = pd.read_sql("SELECT * FROM Students;", conn)

# %%
import bamboolib as bam
bam.enable()
df
# Out:
# /home/conqueror/PsyOp/jupyternv/lib/python3.12/site-packages/bamboolib/__init__.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound
# Success: the bamboolib extension was enabled successfully. You can disable it via 'bam.disable()'. You will now see a magic bamboolib button when you display your dataframes, for example via 'df'
#      student_id  age gender
# 0             1   20      M
# 1             2   20      M
# 2             3   20      M
# 3             4   20      F
# 4             5   20      M
# ..          ...  ...    ...
# 772         773   21      M
# 773         774   19      F
# 774         775   19      F
# 775         776   20      M
# 776         777   19      M
#
# [777 rows x 3 columns]
